# %%
import pandas as pd
df=pd.DataFrame
df=pd.read_excel('Ahteshmul.xlsx')
df=df.set_index('S No.')
df
# Out:
#                                      Name of the company  \
# S No.
# 1                                       SPARK SKILLS LLP
# 2                                              VENUEMONK
# 3                       MUDGAL ENGINEERS PRIVATE LIMITED
# 4                 INSIDEOUT TECHNOLOGIES PRIVATE LIMITED
# 5                            SSGNS FOODS PRIVATE LIMITED
# 6                          FULLTANK TECHNOLOGIES PVT LTD
# 7                             KESHIHA SERVICES PVT. LTD.
# 8                     TINYTAPPS SOFTWARE PRIVATE LIMITED
# 9                                           HEALTHSAATHI
# 10                                          GOEVENTZ.COM
# 11                         DUCERE TECHNOLOGIES PVT. LTD.
# 12                       SMARTSENSE TECHNOLOGIES PVT LTD
# 13                   POP ONLINE SERVICES PRIVATE LIMITED
# 14                                            INDIO LABS
# 15                                         MYCLOUDBAZAAR
# ...

# %%
df[df['Remarks']=='Invalid no.']='Invalid Number' 
df[df['Remarks']=='Invalid no']='Invalid Number' 
df[df['Remarks']=='invalid no.']='Invalid Number'
df[df['Remarks']=='invalid no']='Invalid Number' 
df[df['Remarks']=='Invalid number']='Invalid Number' 
df[df['Remarks']=="Doesn't exist"]='Invalid Number' 
df[df['Remarks']=="Does not exist"]='Invalid Number' 
df[df['Remarks']=="Invalid numder"]='Invalid Number' 
#df[df['Remarks']=="Invalid"]='Invalid Number' 
df[df['Remarks']=="switch off"]='Invalid Number'
df[df['Remarks']=="Invalid"]='Invalid Number'
#df[df['Remarks']=="Invalid"]='Invalid Number'
df[df['Remarks']=="Toll-free no."]='Invalid Number'
df[df['Remarks']=="wrong Number"]='Invalid Number'
df[df['Remarks']=="Doesnot exist"]='Invalid Number'
df[df['Remarks']=="wrong no"]='Invalid Number'
df[df['Remarks']=="Toll-free, no response"]='Invalid Number'

# %%
df[df['Remarks']=="Not interest"]='Not interested'
df[df['Remarks']=="Not required"]='Not interested'
df[df['Remarks']=="Not Interested"]='Not interested'
df[df['Remarks']=="not interested"]='Not interested'
df[df['Remarks']=="No requirement"]='Not interested'
df[df['Remarks']=="Not interseted"]='Not interested'
df[df['Remarks']=="Don't call again"]='Not interested'
df[df['Remarks']=="Hiring staff is available"]='Not interested'
df[df['Remarks']=="Own Hr recruiter"]='Not interested'
df[df['Remarks']=="Not accepting"]='Not interested'
df[df['Remarks']=="Already received calling from Blitzjobs, stop calling"]='Not interested'
df[df['Remarks']=="Not respond"]='Not interested'
df[df['Remarks']=="Own HR recruiter"]='Not interested'
df[df['Remarks']=="no respose"]='Not interested'
df[df['Remarks']=="Not looking for consultancy"]='Not interested'
df[df['Remarks']=="Received then disconnect the call"]='Not interested'
df[df['Remarks']=="No response"]='Not interested'
df[df['Remarks']=="Disconnect the call"]='Not interested'
df[df['Remarks']=="no hiring"]='Not interested'
df[df['Remarks']=="time given then not received"]='Not interested'
df[df['Remarks']=="No need"]='Not interested'
df[df['Remarks']=="No need,"]='Not interested'

# %%
df[df['Remarks']=="no response"]='Unreachable'
df[df['Remarks']=="not received"]='Unreachable'
df[df['Remarks']=="No response"]='Unreachable'
df[df['Remarks']=="Not Received"]='Unreachable'
df[df['Remarks']=="Busy"]='Unreachable'
df[df['Remarks']=="Not received"]='Unreachable'

# %%
df[df['Remarks']=="no hiring at that time"]='Not Hiring Currently'
df[df['Remarks']=="no hiring currently"]='Not Hiring Currently'
df[df['Remarks']=="not hiring at that time"]='Not Hiring Currently'
df[df['Remarks']=="Call after one month"]='Not Hiring Currently'
df[df['Remarks']=="Currently not hiring"]='Not Hiring Currently'
df[df['Remarks']=="Not looking at that time"]='Not Hiring Currently'
df[df['Remarks']=="no hiring"]='Not Hiring Currently'

# %%
df[df['Remarks']=="Temporarily out of services"]='Out of Service'
df[df['Remarks']=="Temporarily ot of service"]='Out of Service'
df[df['Remarks']=="either switch off or out of service"]='Out of Service'
df[df['Remarks']=="Out of service"]='Out of Service'
df[df['Remarks']=="Temporary out of service"]='Out of Service'

# %%
df[df['Remarks']=="out of network"]='Unreachable'
df[df['Remarks']=="incoming call not available"]='Unreachable'
df[df['Remarks']=="Not available  "]='Unreachable'
df[df['Remarks']=="Switch off"]='Unreachable'
df[df['Remarks']=="service not available"]='Unreachable'
df[df['Remarks']=="switch off"]='Unreachable'

# %%
                                                              
df_1=df['Remarks'].value_counts()
df_1
# Out:
# Invalid Number                                                             157
# Unreachable                                                                 94
# Not interested                                                              57
# Received call                                                               13
# Not Hiring Currently                                                        10
# Out of Service                                                               8
# send email for purposal                                                      6
# No required                                                                  5
# received call                                                                4
# send email                                                                   4
# Meeting                                                                      3
# Interesting for future hiring                                                2
# ...

# %%
import matplotlib.pyplot as plt
df_1.plot(kind='bar')
